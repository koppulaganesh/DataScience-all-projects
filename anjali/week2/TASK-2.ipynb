# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
A=pd.read_csv("C:\\Users\\intel\\Downloads\\WL_task2_ProdData_2023_versionD.csv")
A
# Out:
#       Unnamed: 0                     Date       Energy  Resistance  Current  \
# 0          16645  2023-03-10 16:06:05.180  5279.587891       272.0     7.10
# 1          16650  2023-03-10 16:06:59.390  5284.775879       270.0     7.13
# 2          16651  2023-03-10 16:00:49.570  5229.563965       267.0     7.15
# 3          16660  2023-03-10 16:44:37.850  5402.745117       273.0     7.16
# 4          16661  2023-03-10 16:45:25.860  5341.735840       274.0     7.10
# ...          ...                      ...          ...         ...      ...
# 8448       94288  2023-08-08 14:11:31.360  5510.055176       277.0     7.16
# 8449       94289  2023-08-08 14:00:20.180  5404.756836       277.0     7.09
# 8450       94290  2023-08-08 14:01:13.470  5384.125000       276.0     7.10
# 8451       94291  2023-08-08 14:06:30.710  5395.432129       277.0     7.10
# 8452       94292  2023-08-08 14:07:19.430  5414.668945       278.0     7.10
#
# ...

# %% [markdown]
# ### Capture the range of each feature(power,energy,voltage,resistane)
#        For capturing the range(ex:Mean,median,minimum,maximum,) mostly we have to use boxplot

# %% [markdown]
# ### Power

# %%
sns.boxplot(x="id",y="Power",data=A,palette="CMRmap")
f1={'family':'Cambria','size':'14','color':'red'}
plt.xlabel("Id",size=14,color="red",fontdict=f1)
plt.ylabel("Power",size=14,color="red",fontdict=f1)
plt.title("BOX PLOT",fontdict=f1)
# Out:
# Text(0.5, 1.0, 'BOX PLOT')

# %% [markdown]
# ### Energy

# %%
sns.boxplot(x="id",y="Energy",data=A,palette="seismic")
plt.xlabel("Id",size=14,color="red",fontdict=f1)
plt.ylabel("Energy",size=14,color="red",fontdict=f1)
plt.title("BOX PLOT",fontdict=f1)
# Out:
# Text(0.5, 1.0, 'BOX PLOT')

# %% [markdown]
# ### Voltage

# %%
sns.boxplot(x="id",y="Voltage",data=A,palette="cool")
plt.xlabel("Id",size=14,color="red",fontdict=f1)
plt.ylabel("Voltage",size=14,color="red",fontdict=f1)
plt.title("BOX PLOT",fontdict=f1)
# Out:
# Text(0.5, 1.0, 'BOX PLOT')

# %% [markdown]
# ### Resistance

# %%
sns.boxplot(x="id",y="Resistance",data=A,palette="winter")
plt.xlabel("Id",size=14,color="red",fontdict=f1)
plt.ylabel("Resistance",size=14,color="red",fontdict=f1)
plt.title("BOX PLOT",fontdict=f1)
# Out:
# Text(0.5, 1.0, 'BOX PLOT')

# %% [markdown]
# ### Capture the count of predictions

# %%
a=sns.countplot(x="prediction",data=A,palette="cool",edgecolor="black")
for p in a.patches:
    a.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
          ha='center', va='baseline')

# %% [markdown]
# ### Capture the data of feature score throught out the dates(serie)

# %% [markdown]
# ### By using Seaborn

# %%
A1=A['Date'] = pd.to_datetime(A['Date'])
A1=A_sorted = A.sort_values(by='Date')

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x="Date",y="score",data=A1)
plt.xlabel("Date",size=18,color="red",fontdict=f1)
plt.ylabel("Score",size=18,color="red",fontdict=f1)
plt.title("LINE PLOT",size=20,fontdict=f1)
plt.show()

# %% [markdown]
# ### By using Plotly

# %%
px.line(A1, x='Date', y="score", template = 'plotly_dark')
# Out:
# <div>                            <div id="003ba85b-b678-45d2-8afd-b04ec3e15d97" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("003ba85b-b678-45d2-8afd-b04ec3e15d97")) {                    Plotly.newPlot(                        "003ba85b-b678-45d2-8afd-b04ec3e15d97",                        [{"hovertemplate":"Date=%{x}<br>score=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2023-03-02T15:03:29.070000","2023-03-02T15:04:37.700000","2023-03-02T15:05:33.680000","2023-03-02T15:06:38.120000","2023-03-02T15:07:41.800000","2023-03-02T15:08:37.740000","2023-03-02T15:09:43.650000","2023-03-02T15:10:48.120000","2023-03-02T15:11:42.850000","2023-03-02
# ...

# %% [markdown]
# ![TIMESERIES](newplot.png)
