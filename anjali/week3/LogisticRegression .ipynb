# %% [markdown]
# TITANIC DATA

# %% [markdown]
# Problem statement/requirement: To know the Survived data/members

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
#pyforest ---it is used to import all the libraries(like pandas,matplotlib)

# %%
M=pd.read_csv("C:\\Users\\intel\\Desktop\\Dataset\\archive\\train.csv")
M
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
M.shape
# Out:
# (891, 12)

# %%
M.isna().sum()  #cheking how many null values present in dataset
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
M.info()     #used to know the data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
from sklearn import preprocessing                    #import label encoder
label_encoder= preprocessing.LabelEncoder()          #label_encoder object knows how to understand word labels
M['Sex'] = label_encoder.fit_transform(M['Sex'])     #Encode labels in  column 'Gender' 
M['Sex'].value_counts()                              #converting male as 1 and female as 2
# Out:
# Sex
# 1    577
# 0    314
# Name: count, dtype: int64

# %%
M1=M.drop(['Ticket','Cabin','Name'],axis=1)
M1
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0              1         0       3    1  22.0      1      0   7.2500        S
# 1              2         1       1    0  38.0      1      0  71.2833        C
# 2              3         1       3    0  26.0      0      0   7.9250        S
# 3              4         1       1    0  35.0      1      0  53.1000        S
# 4              5         0       3    1  35.0      0      0   8.0500        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 886          887         0       2    1  27.0      0      0  13.0000        S
# 887          888         1       1    0  19.0      0      0  30.0000        S
# 888          889         0       3    0   NaN      1      2  23.4500        S
# 889          890         1       1    1  26.0      0      0  30.0000        C
# 890          891         0       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 9 columns]

# %%
M["Age"].median()      #it gives the median value of age
# Out:
# 28.0

# %%
M1["Age"]=M1["Age"].fillna(value=28)   #Filling the null values using fillna (here fill age value in age column with NaN)
M1
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0              1         0       3    1  22.0      1      0   7.2500        S
# 1              2         1       1    0  38.0      1      0  71.2833        C
# 2              3         1       3    0  26.0      0      0   7.9250        S
# 3              4         1       1    0  35.0      1      0  53.1000        S
# 4              5         0       3    1  35.0      0      0   8.0500        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 886          887         0       2    1  27.0      0      0  13.0000        S
# 887          888         1       1    0  19.0      0      0  30.0000        S
# 888          889         0       3    0  28.0      1      2  23.4500        S
# 889          890         1       1    1  26.0      0      0  30.0000        C
# 890          891         0       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 9 columns]

# %%
M1.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       2
# dtype: int64

# %%
M1["Embarked"].value_counts()       #for embarked values count
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
A=M1.groupby("Survived")
A["Embarked"].value_counts()        #groupby multiple columns
# Out:
# Survived  Embarked
# 0         S           427
#           C            75
#           Q            47
# 1         S           217
#           C            93
#           Q            30
# Name: count, dtype: int64

# %%
M1["Embarked"]=M1['Embarked'].fillna(value='s') #Filling the embarked null values with "s" because it contains more "s" values
M1
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0              1         0       3    1  22.0      1      0   7.2500        S
# 1              2         1       1    0  38.0      1      0  71.2833        C
# 2              3         1       3    0  26.0      0      0   7.9250        S
# 3              4         1       1    0  35.0      1      0  53.1000        S
# 4              5         0       3    1  35.0      0      0   8.0500        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 886          887         0       2    1  27.0      0      0  13.0000        S
# 887          888         1       1    0  19.0      0      0  30.0000        S
# 888          889         0       3    0  28.0      1      2  23.4500        S
# 889          890         1       1    1  26.0      0      0  30.0000        C
# 890          891         0       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 9 columns]

# %%
M1.isna().sum()              # again check if any null values are there in dataset
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
from sklearn import preprocessing                   
label_encoder= preprocessing.LabelEncoder()                    #Create a LabelEncoder object from importing sklearn
M1['Embarked'] = label_encoder.fit_transform(M1['Embarked'])   #Fit and transform the 'Embarked' column in the DataFrame M1
M1['Embarked'].value_counts()                                  #Display the counts of each unique value in the 'Embarked' column
#categorical data (like 'Embarked' with categories 'C', 'Q', and 'S') that you want to convert into numerical values
#for machine learning algorithms that require numerical input.
# Out:
# Embarked
# 2    644
# 0    168
# 1     77
# 3      2
# Name: count, dtype: int64

# %%
M1 = M1[M1['Embarked'] != 3]    #Removing that embarked no. 3
M1
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0              1         0       3    1  22.0      1      0   7.2500         2
# 1              2         1       1    0  38.0      1      0  71.2833         0
# 2              3         1       3    0  26.0      0      0   7.9250         2
# 3              4         1       1    0  35.0      1      0  53.1000         2
# 4              5         0       3    1  35.0      0      0   8.0500         2
# ..           ...       ...     ...  ...   ...    ...    ...      ...       ...
# 886          887         0       2    1  27.0      0      0  13.0000         2
# 887          888         1       1    0  19.0      0      0  30.0000         2
# 888          889         0       3    0  28.0      1      2  23.4500         2
# 889          890         1       1    1  26.0      0      0  30.0000         0
# 890          891         0       3    1  32.0      0      0   7.7500         1
#
# [889 rows x 9 columns]

# %%
sns.countplot(x="Embarked",data=M1,palette="cool",edgecolor="black",hue='Survived') #0-means not survived,1-means survived
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
M1.corr()     #used to know the correlation
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005028 -0.035330  0.043136  0.031319 -0.057686
# Survived       -0.005028  1.000000 -0.335549 -0.541585 -0.069822 -0.034040
# Pclass         -0.035330 -0.335549  1.000000  0.127741 -0.336512  0.081656
# Sex             0.043136 -0.541585  0.127741  1.000000  0.086506 -0.116348
# Age             0.031319 -0.069822 -0.336512  0.086506  1.000000 -0.232543
# SibSp          -0.057686 -0.034040  0.081656 -0.116348 -0.232543  1.000000
# Parch          -0.001657  0.083151  0.016824 -0.247508 -0.171485  0.414542
# Fare            0.012703  0.255290 -0.548193 -0.179958  0.093707  0.160887
# Embarked        0.013166 -0.169718  0.164681  0.110320 -0.020933  0.068900
#
#                 Parch      Fare  Embarked
# PassengerId -0.001657  0.012703  0.013166
# Survived     0.083151  0.255290 -0.169718
# Pclass       0.016824 -0.548193  0.164681
# Sex         -0.247508 -0.179958  0.110320
# ...

# %%
plt.figure(figsize=(18,8))
M1.plot(x="Survived",y=['SibSp','Parch'],kind="bar")
plt.show()

# %%
sns.heatmap(M1.corr())     #mostly used to know the column importance >here 1.0-positive correlation, -0.4--negitive correlation
                           #here orange is positive correlation so we have to add these two
# Out:
# <Axes: >

# %%
#ADDING THE POSITIVE CORRELATION COLUMN
M1['family']=M1['SibSp']+M1['Parch']+1      #Creating a new 'family' column
M1=M1.drop(['SibSp','Parch'],axis=1)        #Dropping 'SibSp' and 'Parch' columns
M1=M1.drop('PassengerId',axis=1)
M1=M1.drop('Embarked',axis=1)
M1
# Out:
#      Survived  Pclass  Sex   Age     Fare  family
# 0           0       3    1  22.0   7.2500       2
# 1           1       1    0  38.0  71.2833       2
# 2           1       3    0  26.0   7.9250       1
# 3           1       1    0  35.0  53.1000       2
# 4           0       3    1  35.0   8.0500       1
# ..        ...     ...  ...   ...      ...     ...
# 886         0       2    1  27.0  13.0000       1
# 887         1       1    0  19.0  30.0000       1
# 888         0       3    0  28.0  23.4500       4
# 889         1       1    1  26.0  30.0000       1
# 890         0       3    1  32.0   7.7500       1
#
# [889 rows x 6 columns]

# %% [markdown]
# ### Preparing the data for a machine learning model (creating a feature matrix)

# %%
# Model build
x=M1.drop('Survived',axis=1).values    # Feature matrix x (input data)----drop Survived data and send all the data to x
y=M1['Survived'].values                # Target variable y (output/label)---only send Survived data to y

# %% [markdown]
# #### Importing the necessary modules for logistic regression and train-test splitting from scikit-learn.

# %%
#for logistic regression
from sklearn.linear_model import LogisticRegression                #importing the model from sklearn
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Spliting the data into training and testing sets

# %%
#x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=100)

# %% [markdown]
# ### Create a logistic regression model

# %%
lr= LogisticRegression()

# %% [markdown]
# ### Fit the model on the training data

# %%
lr.fit(x_train, y_train)    #sending data to train 70%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 lr.fit(x_train, y_train)
#
# NameError: name 'lr' is not defined

# %% [markdown]
# ### Make predictions on the testing data

# %%
lrpred = lr.predict(x_test)

# %% [markdown]
# ### Evaluate the model's accuracy

# %%
#import accuracy_score from sklearn.metrics
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, lrpred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.7715355805243446

# %%
# or use below code for above steps
#from sklearn.metrics import accuracy_score     
#lr=LogisticRegression()
#lr.fit(x_train,y_train)         # sending data to train-70%
#lrpred=lr.predict(x_test)      #sendinhg data to test-30%  
#accuracy_score(y_test,lrpred)

# %%
##if accuracy is not satisfied with above model,next we have to go for optimized techniques

# %% [markdown]
# GridSearchCV for hyperparameter tuning on a logistic regression model.
# This is a good approach to find the optimal hyperparameter values for your model.

# %% [markdown]
# #### Import required libraries for hyperparameter tuning from sklearn

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# #### Define the hyperparameter grid

# %%
c_space = np.logspace(-5, 8, 15)     #c_space is a range of values for the hyperparameter C.
param_grid = {'C': c_space}    #param_grid is a dictionary specifying the hyperparameters to search and their respective ranges.

# %% [markdown]
# #### Create a logistic regression model

# %%
lr = LogisticRegression()

# %% [markdown]
# #### Create a GridSearchCV object

# %%
logreg_cv = GridSearchCV(lr, param_grid, cv=5) 
#GridSearchCV performs a cross-validated grid search over the hyperparameter grid, trying all possible combinations.

# %% [markdown]
# #### Fit the model with hyperparameter tuning on the training data

# %%
logreg_cv.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 logreg_cv.fit(x_train, y_train)
#
# NameError: name 'logreg_cv' is not defined

# %% [markdown]
# #### Print the best hyperparameters and the corresponding score

# %%
#logreg_cv.best_params_ gives you the best hyperparameters found during the search
print("Tuned Logistic Regression Parameters: {}".format(logreg_cv.best_params_))
print("Best score is {}".format(logreg_cv.best_score_))

# %%
#from sklearn.model_selection import GridSearchCV      # also known as HYPER PARAMETER TUNING
#c_space =np.logspace(-5,8,15)
#param_grid ={'C':c_space}
#logreg_cv = GridSearchCV(lr,param_grid, cv=5)
#print("Tuned Logistic Regression Parameters: {}".format(logreg_cv.best_params_))
#print("Best score is {}".format(logreg_cv.best_score_))
