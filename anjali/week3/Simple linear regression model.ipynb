# %% [markdown]
# ### Predict an individual's salary based on their years of experience.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
D=pd.read_csv("C:\\Users\\intel\\Desktop\\Dataset\\Salary_Data.csv")
D
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
D.isna().sum()                #checking the null values
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %% [markdown]
# ## scikit-learn

# %% [markdown]
#  scikit-learn is a popular machine learning library for Python that provides simple and efficient tools for data analysis and
#  modeling.
#
#  It is widely used for tasks such as classification, regression, clustering, dimensionality reduction, and more.
#
#  The library is built on NumPy, SciPy, and Matplotlib, and it integrates well with other Python libraries.

# %% [markdown]
# ### Assuming  features x and target variable y

# %%
#creating  Feature matrix
x= D.iloc[:, :1].values               #selecting all rows (:) and the first column (:1) & storing it in the variable x
y= D.iloc[:,-1].values               #selecting all rows (:) and the last column (-1) & storing it in the variable y

# %% [markdown]
# ### Split the data into training and testing sets

# %%
# for model selection---import train_test_split function from the sklearn.model_selection
from sklearn.model_selection import train_test_split
x_train ,x_test, y_train, y_test = train_test_split (X,y,test_size=0.2,random_state=0)  
# means that 20% of the data will be used for testing,and the remaining 80% will be used for training.(use30% also for testing) 
#random_state=0 means-random split into training and testing sets will be the same every time you run the code.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # for model selection---import train_test_split function from the sklearn.model_selection
#       2 from sklearn.model_selection import train_test_split
# ----> 3 x_train ,x_test, y_train, y_test = train_test_split (X,y,test_size=0.2,random_state=0)
#
# NameError: name 'X' is not defined

# %% [markdown]
# ### Create a linear regression model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()   
#regressor is a variable (or an object) that you are using to represent an instance of the LinearRegression class.

# %% [markdown]
# ### Training the model

# %%
regressor.fit(x_train, y_train)              #to fit the model to training data.
# Out:
# LinearRegression()

# %% [markdown]
# ### Making predictions on the test set

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# ### Evaluating the model

# %%
from sklearn.metrics import mean_squared_error 
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 12823412.298126549

# %% [markdown]
# ### Plotting the regression line

# %%
plt.scatter(X_train, y_train, color='black', label='Actual Data')
plt.plot(X_train, regressor.predict(X_train), color='blue', linewidth=2, label='Regression Line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.show()   #if the data points are near to the regression line---it predict the best model or best fit

# %%
plt.scatter(X_test, y_test, color='red', label='Test Data')  # Plot only test data points
plt.plot(X_test, regressor.predict(X_test), color='blue', linewidth=2, label='Regression Line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.show()

# %% [markdown]
# ### Plot both test and train data in one plot

# %%
plt.scatter(X_train, y_train, color='black', label='Training Data')
plt.scatter(X_test, y_test, color='red', label='Test Data')  # Add test data points in a different color
plt.plot(X_train, regressor.predict(X_train), color='blue', linewidth=2, label='Regression Line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.show()
