# %% [markdown]
# #                                                          PANDAS

# %% [markdown]
# ## 1.Series

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
my_data = [10,20,30]
arr = np.array(my_data)
d = {'a':10,'b':20,'c':30}

# %%
pd.Series(data = my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_data,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
d
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
labels
# Out:
# ['a', 'b', 'c']

# %%
pd.Series(data=[sum,print,len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
name1 =pd.Series([1,2,3,4],['anjali','kaveri','sid','anshu'])

# %%
name1
# Out:
# anjali    1
# kaveri    2
# sid       3
# anshu     4
# dtype: int64

# %%
name1['sid']
# Out:
# 3

# %%
name2 = pd.Series([1,2,3,4],['anjali','kaveri','suni','anshu'])

# %%
name2
# Out:
# anjali    1
# kaveri    2
# suni      3
# anshu     4
# dtype: int64

# %%
name1*name2
# Out:
# anjali     1.0
# anshu     16.0
# kaveri     4.0
# sid        NaN
# suni       NaN
# dtype: float64

# %%
data = pd.Series([1,2,3],['aa','bb','cc'])

# %%
data_ = pd.Series([1,2,3],['aa','dd','cc'])

# %%
data+data_
# Out:
# aa    2.0
# bb    NaN
# cc    6.0
# dd    NaN
# dtype: float64

# %% [markdown]
# ## 2.Data frames

# %%
import numpy as np

import pandas as pd

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(randn(4,3),['A','B','C','D'],['W','X','Y'])

# %%
df
# Out:
#           W         X         Y
# A  2.706850  0.628133  0.907969
# B  0.503826  0.651118 -0.319318
# C -0.848077  0.605965 -2.018168
# D  0.740122  0.528813 -0.589001

# %%
df.W   #OR df['W']
# Out:
# A    2.706850
# B    0.503826
# C   -0.848077
# D    0.740122
# Name: W, dtype: float64

# %%
type[df['W']]
# Out:
# type[A    2.706850
# B    0.503826
# C   -0.848077
# D    0.740122
# Name: W, dtype: float64]

# %%
df[['W','X']]
# Out:
#           W         X
# A  2.706850  0.628133
# B  0.503826  0.651118
# C -0.848077  0.605965
# D  0.740122  0.528813

# %%
df['new']=df['W']+ df['X']

# %%
df
# Out:
#           W         X         Y       new
# A  2.706850  0.628133  0.907969  3.334983
# B  0.503826  0.651118 -0.319318  1.154944
# C -0.848077  0.605965 -2.018168 -0.242112
# D  0.740122  0.528813 -0.589001  1.268936

# %%
df.drop('new',axis=0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df.drop('new',axis=0,inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.drop('D')
# Out:
#           W         X         Y       new
# A  2.706850  0.628133  0.907969  3.334983
# B  0.503826  0.651118 -0.319318  1.154944
# C -0.848077  0.605965 -2.018168 -0.242112

# %%
df.loc['D','X']
# Out:
# 0.5288134940893595

# %%
df.loc[['A','B'],['X','Y']]
# Out:
#           X         Y
# A  0.628133  0.907969
# B  0.651118 -0.319318

# %%
df
# Out:
#           W         X         Y       new
# A  2.706850  0.628133  0.907969  3.334983
# B  0.503826  0.651118 -0.319318  1.154944
# C -0.848077  0.605965 -2.018168 -0.242112
# D  0.740122  0.528813 -0.589001  1.268936

# %%
booldf= df>0

# %%
df[booldf]
# Out:
#           W         X         Y       new
# A  2.706850  0.628133  0.907969  3.334983
# B  0.503826  0.651118       NaN  1.154944
# C       NaN  0.605965       NaN       NaN
# D  0.740122  0.528813       NaN  1.268936

# %%
df[df>0]
# Out:
#           W         X         Y       new
# A  2.706850  0.628133  0.907969  3.334983
# B  0.503826  0.651118       NaN  1.154944
# C       NaN  0.605965       NaN       NaN
# D  0.740122  0.528813       NaN  1.268936

# %%
boolser = df['W']>0

# %%
result = df[boolser]

# %%
result
# Out:
#           W         X         Y       new
# A  2.706850  0.628133  0.907969  3.334983
# B  0.503826  0.651118 -0.319318  1.154944
# D  0.740122  0.528813 -0.589001  1.268936

# %% [markdown]
# ### By using EXCEL & CSV file

# %%
a=pd.read_csv("C:\\Users\\intel\\Desktop\\Dataset\\covid.csv")

# %%
df=pd.DataFrame(a)

# %%
df
# Out:
#      Serial Number           Country  Total Cases Total Deaths  \
# 0                1               USA  104,196,861    1,132,935
# 1                2             India   44,682,784      530,740
# 2                3            France   39,524,311      164,233
# 3                4           Germany   37,779,833      165,711
# 4                5            Brazil   36,824,580      697,074
# ..             ...               ...          ...          ...
# 226            227  Diamond Princess          712           13
# 227            228      Vatican City           29          NaN
# 228            229    Western Sahara           10            1
# 229            230        MS Zaandam            9            2
# 230            231           Tokelau            5          NaN
#
#     Total Recovered Active Cases     Total Test     Population
# 0       101,322,779    1,741,147  1,159,832,679    334,805,269
# 1        44,150,289        1,755    915,265,788  1,406,631,776
# ...

# %% [markdown]
# ### DataFrame by using dictionary

# %%
dic={"name":["anjali","sid","kavi","aa","bb","cc","dd","ee"],"roll_no":[1,2,3,4,5,6,7,8],"perc":["90.2","89.3","98","70.6","89","90.6","90","99.5"],"marks":["100","200","300","400","500","600","700","800"]}

# %%
cls=pd.DataFrame(dic)

# %%
cls
# Out:
#      name  roll_no  perc marks
# 0  anjali        1  90.2   100
# 1     sid        2  89.3   200
# 2    kavi        3    98   300
# 3      aa        4  70.6   400
# 4      bb        5    89   500
# 5      cc        6  90.6   600
# 6      dd        7    90   700
# 7      ee        8  99.5   800

# %% [markdown]
# ### By using tuples

# %%
a=[("aa",10,20),("bb",30,40),("cc",50,60),("dd",70,80),("ee",90,100)]

# %%
dd=pd.DataFrame(a)

# %%
dd
# Out:
#     0   1    2
# 0  aa  10   20
# 1  bb  30   40
# 2  cc  50   60
# 3  dd  70   80
# 4  ee  90  100

# %% [markdown]
# ## By using excel and csv file

# %%
a=pd.read_csv("C:\\Users\\intel\\Desktop\\Dataset\\covid.csv")

# %%
df = pd.DataFrame(a)

# %%
df
# Out:
#      Serial Number           Country  Total Cases Total Deaths  \
# 0                1               USA  104,196,861    1,132,935
# 1                2             India   44,682,784      530,740
# 2                3            France   39,524,311      164,233
# 3                4           Germany   37,779,833      165,711
# 4                5            Brazil   36,824,580      697,074
# ..             ...               ...          ...          ...
# 226            227  Diamond Princess          712           13
# 227            228      Vatican City           29          NaN
# 228            229    Western Sahara           10            1
# 229            230        MS Zaandam            9            2
# 230            231           Tokelau            5          NaN
#
#     Total Recovered Active Cases     Total Test     Population
# 0       101,322,779    1,741,147  1,159,832,679    334,805,269
# 1        44,150,289        1,755    915,265,788  1,406,631,776
# ...

# %%
df.head(50)
# Out:
#     Serial Number       Country  Total Cases Total Deaths Total Recovered  \
# 0               1           USA  104,196,861    1,132,935     101,322,779
# 1               2         India   44,682,784      530,740      44,150,289
# 2               3        France   39,524,311      164,233      39,264,546
# 3               4       Germany   37,779,833      165,711      37,398,100
# 4               5        Brazil   36,824,580      697,074      35,919,372
# 5               6         Japan   32,588,442       68,399      21,567,425
# 6               7      S. Korea   30,197,066       33,486      29,740,877
# 7               8         Italy   25,453,789      186,833      25,014,986
# 8               9            UK   24,274,361      204,171      24,020,088
# 9              10        Russia   21,958,696      395,108      21,356,008
# 10             11        Turkey   17,042,722      101,492             NaN
# 11             12         Spain   13,731,478      118,434      13,557,699
# ...

# %%
df.tail()
# Out:
#      Serial Number           Country Total Cases Total Deaths Total Recovered  \
# 226            227  Diamond Princess         712           13             699
# 227            228      Vatican City          29          NaN              29
# 228            229    Western Sahara          10            1               9
# 229            230        MS Zaandam           9            2               7
# 230            231           Tokelau           5          NaN             NaN
#
#     Active Cases Total Test Population
# 226            0        NaN        NaN
# 227            0        NaN        799
# 228            0        NaN    626,161
# 229            0        NaN        NaN
# 230            5        NaN      1,378

# %%
df.tail(15)
# Out:
#      Serial Number                Country Total Cases Total Deaths  \
# 216            217                  Nauru       4,621            1
# 217            218               Anguilla       3,904           12
# 218            219                  Macao       3,488          120
# 219            220  Saint Pierre Miquelon       3,452            2
# 220            221      Wallis and Futuna       3,427            7
# 221            222                 Tuvalu       2,805          NaN
# 222            223           Saint Helena       2,166          NaN
# 223            224       Falkland Islands       1,930          NaN
# 224            225             Montserrat       1,403            8
# 225            226                   Niue         747          NaN
# 226            227       Diamond Princess         712           13
# 227            228           Vatican City          29          NaN
# 228            229         Western Sahara          10            1
# ...

# %%
df.shape
# Out:
# (231, 8)

# %%
df[3:15:3]
# Out:
#     Serial Number   Country Total Cases Total Deaths Total Recovered  \
# 3               4   Germany  37,779,833      165,711      37,398,100
# 6               7  S. Korea  30,197,066       33,486      29,740,877
# 9              10    Russia  21,958,696      395,108      21,356,008
# 12             13   Vietnam  11,526,508       43,186      10,612,479
#
#    Active Cases   Total Test   Population
# 3       216,022  122,332,384   83,883,596
# 6       422,703   15,804,065   51,329,899
# 9       207,580  273,400,000  145,805,947
# 12      870,843   85,826,548   98,953,541

# %%
df["Total Deaths"]
# Out:
# 0      1,132,935
# 1        530,740
# 2        164,233
# 3        165,711
# 4        697,074
#          ...
# 226           13
# 227          NaN
# 228            1
# 229            2
# 230          NaN
# Name: Total Deaths, Length: 231, dtype: object

# %%
df.describe()
# Out:
#        Serial Number
# count     231.000000
# mean      116.000000
# std        66.828138
# min         1.000000
# 25%        58.500000
# 50%       116.000000
# 75%       173.500000
# max       231.000000

# %%
for a in df.iterrows():
    print(a)
# Out:
# (0, Serial Number                  1
# Country                      USA
# Total Cases          104,196,861
# Total Deaths           1,132,935
# Total Recovered      101,322,779
# Active Cases           1,741,147
# Total Test         1,159,832,679
# Population           334,805,269
# Name: 0, dtype: object)
# (1, Serial Number                  2
# Country                    India
# Total Cases           44,682,784
# Total Deaths             530,740
# Total Recovered       44,150,289
# Active Cases               1,755
# Total Test           915,265,788
# Population         1,406,631,776
# Name: 1, dtype: object)
# (2, Serial Number                3
# Country                 France
# Total Cases         39,524,311
# Total Deaths           164,233
# Total Recovered     39,264,546
# Active Cases            95,532
# Total Test         271,490,188
# Population          65,584,518
# Name: 2, dtype: object)
# (3, Serial Number                4
# Country                Germany
# ...

# %%
df.drop_duplicates()
# Out:
#      Serial Number                Country  Total Cases Total Deaths  \
# 0                1                    USA  104,196,861    1,132,935
# 1                2                  India   44,682,784      530,740
# 2                3                 France   39,524,311      164,233
# 3                4                Germany   37,779,833      165,711
# 4                5                 Brazil   36,824,580      697,074
# ..             ...                    ...          ...          ...
# 217            218               Anguilla        3,904           12
# 218            219                  Macao        3,488          120
# 219            220  Saint Pierre Miquelon        3,452            2
# 220            221      Wallis and Futuna        3,427            7
# 224            225             Montserrat        1,403            8
#
#     Total Recovered Active Cases     Total Test     Population
# 0       101,322,779    1,741,147  1,159,832,679    334,805,269
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      Serial Number                Country  Total Cases Total Deaths  \
# 0                1                    USA  104,196,861    1,132,935
# 1                2                  India   44,682,784      530,740
# 2                3                 France   39,524,311      164,233
# 3                4                Germany   37,779,833      165,711
# 4                5                 Brazil   36,824,580      697,074
# ..             ...                    ...          ...          ...
# 217            218               Anguilla        3,904           12
# 218            219                  Macao        3,488          120
# 219            220  Saint Pierre Miquelon        3,452            2
# 220            221      Wallis and Futuna        3,427            7
# 224            225             Montserrat        1,403            8
#
#     Total Recovered Active Cases     Total Test     Population
# 0       101,322,779    1,741,147  1,159,832,679    334,805,269
# ...

# %% [markdown]
# ### loc's

# %%
df.loc[20]
# Out:
# Serial Number              21
# Country                Poland
# Total Cases         6,380,225
# Total Deaths          118,736
# Total Recovered     5,335,940
# Active Cases          925,549
# Total Test         38,118,630
# Population         37,739,785
# Name: 20, dtype: object

# %%
df.loc[2,["Population"]]
# Out:
# Population    65,584,518
# Name: 2, dtype: object

# %%
df.loc[3:8,"Total Test"]
# Out:
# 3    122,332,384
# 4     63,776,166
# 5     92,144,639
# 6     15,804,065
# 7    265,478,247
# 8    522,526,476
# Name: Total Test, dtype: object

# %%
df.loc[2:5,["Country","Population","Total Test"]]
# Out:
#    Country   Population   Total Test
# 2   France   65,584,518  271,490,188
# 3  Germany   83,883,596  122,332,384
# 4   Brazil  215,353,593   63,776,166
# 5    Japan  125,584,838   92,144,639

# %%
df.loc[100:200:2,["Population","Country"]]
# Out:
#      Population              Country
# 100  19,470,234               Zambia
# 102   2,441,162             Botswana
# 104     627,950           Montenegro
# 106  45,350,148              Algeria
# 108  15,331,428             Zimbabwe
# 110  33,089,461           Mozambique
# 115   6,728,271           Kyrgyzstan
# 118   1,406,585  Trinidad and Tobago
# 120  32,395,450                Ghana
# 122  48,432,863               Uganda
# 124  17,168,639             Cambodia
# 126  27,911,548             Cameroon
# 128     288,023             Barbados
# 130     176,463      Channel Islands
# 132  95,240,792                  DRC
# 134  20,180,839               Malawi
# 137     290,915        New Caledonia
# 140     794,045               Guyana
# 142     909,466                 Fiji
# 144  45,992,020                Sudan
# 146     567,678           Cabo Verde
# 148  19,364,809                Syria
# 151   2,331,533                Gabon
# 153   9,292,169     Papua New Guinea
# ...

# %% [markdown]
# ### iloc's

# %%
df.iloc[20,5]
# Out:
# '34,322'

# %%
df.iloc[5:10,2:78]
# Out:
#   Total Cases Total Deaths Total Recovered Active Cases   Total Test  \
# 5  32,588,442       68,399      21,567,425   10,952,618   92,144,639
# 6  30,197,066       33,486      29,740,877      422,703   15,804,065
# 7  25,453,789      186,833      25,014,986      251,970  265,478,247
# 8  24,274,361      204,171      24,020,088       50,102  522,526,476
# 9  21,958,696      395,108      21,356,008      207,580  273,400,000
#
#     Population
# 5  125,584,838
# 6   51,329,899
# 7   60,262,770
# 8   68,497,907
# 9  145,805,947

# %%
df.iloc[0:3,0:5]
# Out:
#    Serial Number Country  Total Cases Total Deaths Total Recovered
# 0              1     USA  104,196,861    1,132,935     101,322,779
# 1              2   India   44,682,784      530,740      44,150,289
# 2              3  France   39,524,311      164,233      39,264,546

# %%
df.iloc[:,[1,2,3,4]]
# Out:
#                    Country  Total Cases Total Deaths Total Recovered
# 0                      USA  104,196,861    1,132,935     101,322,779
# 1                    India   44,682,784      530,740      44,150,289
# 2                   France   39,524,311      164,233      39,264,546
# 3                  Germany   37,779,833      165,711      37,398,100
# 4                   Brazil   36,824,580      697,074      35,919,372
# ..                     ...          ...          ...             ...
# 217               Anguilla        3,904           12           3,879
# 218                  Macao        3,488          120           3,357
# 219  Saint Pierre Miquelon        3,452            2           2,449
# 220      Wallis and Futuna        3,427            7             438
# 224             Montserrat        1,403            8           1,376
#
# [195 rows x 4 columns]

# %%
df.iloc[2:10:2,[1,2,3]]
# Out:
#     Country Total Cases Total Deaths
# 2    France  39,524,311      164,233
# 4    Brazil  36,824,580      697,074
# 6  S. Korea  30,197,066       33,486
# 8        UK  24,274,361      204,171

# %%
df.iloc[[1,2,3,4],[1,2,3,4]]
# Out:
#    Country Total Cases Total Deaths Total Recovered
# 1    India  44,682,784      530,740      44,150,289
# 2   France  39,524,311      164,233      39,264,546
# 3  Germany  37,779,833      165,711      37,398,100
# 4   Brazil  36,824,580      697,074      35,919,372

# %%
df.sort_values("Total Cases")
# Out:
#      Serial Number        Country Total Cases Total Deaths Total Recovered  \
# 72              73          Nepal   1,001,102       12,020         989,064
# 71              72       Mongolia   1,007,871        2,179       1,005,658
# 70              71         Panama   1,029,701        8,596       1,020,206
# 69              70        Uruguay   1,032,710        7,609       1,023,939
# 68              69            UAE   1,049,409        2,348       1,032,735
# ..             ...            ...         ...          ...             ...
# 200            201          Niger       9,931          312           8,890
# 132            133            DRC      95,514        1,463          84,264
# 74              75         Latvia     975,355        6,218         968,830
# 131            132  French Guiana      98,028          420          11,254
# 73              74        Belarus     994,037        7,118         985,592
#
#     Active Cases   Total Test  Population
# ...

# %%
df.sort_values("Total Cases",ascending=False)
# Out:
#      Serial Number        Country Total Cases Total Deaths Total Recovered  \
# 73              74        Belarus     994,037        7,118         985,592
# 131            132  French Guiana      98,028          420          11,254
# 74              75         Latvia     975,355        6,218         968,830
# 132            133            DRC      95,514        1,463          84,264
# 200            201          Niger       9,931          312           8,890
# ..             ...            ...         ...          ...             ...
# 68              69            UAE   1,049,409        2,348       1,032,735
# 69              70        Uruguay   1,032,710        7,609       1,023,939
# 70              71         Panama   1,029,701        8,596       1,020,206
# 71              72       Mongolia   1,007,871        2,179       1,005,658
# 72              73          Nepal   1,001,102       12,020         989,064
#
#     Active Cases   Total Test  Population
# ...

# %%
df["Aa"]=df["Active Cases"]+df["Total Deaths"]

# %%
df["Aa"]
# Out:
# 0      1,741,1471,132,935
# 1            1,755530,740
# 2           95,532164,233
# 3          216,022165,711
# 4          208,134697,074
#               ...
# 217                  1312
# 218                 11120
# 219                1,0012
# 220                2,9827
# 224                   198
# Name: Aa, Length: 195, dtype: object

# %%
Bank = pd.read_csv("C:\\Users\\intel\\Downloads\\bank\\Data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 Bank = pd.read_csv("C:\\Users\\intel\\Downloads\\bank\\Data.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...

# %%
df = pd.DataFrame(Bank)

# %%
df

# %%
df.dropna(inplace=True)

# %%
df

# %%
df.loc[df["Surname"].str.contains("A")]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Surname'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 1
# ...

# %%
df['total']=df['Tenure']+df['NumOfProducts'] #df['new']=df['W']+ df['X']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tenure'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ...

# %%
df
# Out:
#           W         X         Y       new
# A  2.706850  0.628133  0.907969  3.334983
# B  0.503826  0.651118 -0.319318  1.154944
# C -0.848077  0.605965 -2.018168 -0.242112
# D  0.740122  0.528813 -0.589001  1.268936

# %%
df.to_csv("C:\\Users\\intel\\Downloads\\bank\\Total.csv")

# %%
df
# Out:
#     RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 0           1    15634602    Hargrave          619    France  Female   42
# 1           2    15647311        Hill          619     Spain  Female   41
# 2           3    15619304        Onio          619    France  Female   42
# 3           4    15701354        Boni          619    France  Female   39
# 4           5    15737888    Mitchell          619     Spain  Female   43
# ..        ...         ...         ...          ...       ...     ...  ...
# 94         95    15676966       Capon          619     Spain    Male   42
# 95         96    15699461  Fiorentini          619     Spain    Male   35
# 96         97    15738721      Graham          619     Spain    Male   41
# 98         99    15604348      Allard          619     Spain    Male   22
# 99        100    15633059     Fanucci          619    France    Male   34
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember   total
# ...

# %%
Bank.info()   #it will give the info..like 100 entries,total coloums=12
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        100 non-null    int64
#  1   CustomerId       100 non-null    int64
#  2   Surname          100 non-null    object
#  3   CreditScore      100 non-null    int64
#  4   Geography        100 non-null    object
#  5   Gender           100 non-null    object
#  6   Age              100 non-null    int64
#  7   Tenure           100 non-null    int64
#  8   Balance          100 non-null    float64
#  9   NumOfProducts    100 non-null    int64
#  10  HasCrCard        99 non-null     float64
#  11  IsActiveMember   100 non-null    int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 9.5+ KB

# %%
Bank['Balance'].mean() #average volue of that balance coloum
# Out:
# 70570.10720000001

# %%
Bank['Balance'].median()
# Out:
# 84559.78

# %%
Bank['Balance'].mode()
# Out:
# 0    0.0
# Name: Balance, dtype: float64

# %%
df.
# Out:
# RowNumber                  6
# CustomerId          15574012
# Surname                  Chu
# CreditScore              619
# Geography              Spain
# Gender                  Male
# Age                       44
# Tenure                     8
# Balance            113755.78
# NumOfProducts              2
# HasCrCard                1.0
# IsActiveMember             0
# total                     10
# Name: 5, dtype: object

# %%
df.Balance.plot()
# Out:
# <Axes: >

# %%
df.CreditScore.plot()
# Out:
# <Axes: >
