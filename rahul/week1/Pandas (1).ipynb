# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # series

# %%
import numpy as np
import pandas as pd

# %%
data=[12,21,2]

# %%
arr1=np.array(data)

# %%
labels=['x','y','z']

# %%
d={"a":12,"b":23,"c":24}

# %%
print(data)
# Out:
# [12, 21, 2]

# %%
print(labels)
# Out:
# ['x', 'y', 'z']

# %%
print(d)
# Out:
# {'a': 12, 'b': 23, 'c': 24}

# %%
arr1
# Out:
# array([12, 21,  2])

# %%
pd.Series(arr1,labels)
# Out:
# x    12
# y    21
# z     2
# dtype: int32

# %%
pd.Series(d)
# Out:
# a    12
# b    23
# c    24
# dtype: int64

# %%
p=pd.Series(labels,arr1)

# %%
p
# Out:
# 12    x
# 21    y
# 2     z
# dtype: object

# %%
pd.Series(arr1)
# Out:
# 0    12
# 1    21
# 2     2
# dtype: int32

# %%
type(p)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### ADDING AND MERGING TWO COMMON SERIES

# %%
ser1=pd.Series([12,2,3,5],['ar','pd','ra','sb'])

# %%
ser2=pd.Series([5,6,4,7],['ar','pd','ra','sb'])

# %%
print(ser1['ra'])
# Out:
# 3

# %%
print(ser1['sb'])
# Out:
# 5

# %%
print(ser1['ar'])
# Out:
# 12

# %%
print(ser1['pd'])
# Out:
# 2

# %%
print(ser1[0])
# Out:
# 12

# %%
print(ser1[0:1])
# Out:
# ar    12
# dtype: int64

# %%
print(ser1[:3])
# Out:
# ar    12
# pd     2
# ra     3
# dtype: int64

# %%
print(ser2)
# Out:
# ar    5
# pd    6
# ra    4
# sb    7
# dtype: int64

# %%
print(ser2[1:])
# Out:
# pd    6
# ra    4
# sb    7
# dtype: int64

# %%
print(ser2['sb'])
# Out:
# 7

# %%
print(ser2['pd'])
# Out:
# 6

# %%
print(ser2[2])
# Out:
# 4

# %%
y=ser1+ser2

# %%
y
# Out:
# ar    17
# pd     8
# ra     7
# sb    12
# dtype: int64

# %%
y=pd.Series()

# %%
ser1*ser2
# Out:
# ar    60
# pd    12
# ra    12
# sb    35
# dtype: int64

# %%
print(np.exp(ser1+ser2))
# Out:
# ar    2.415495e+07
# pd    2.980958e+03
# ra    1.096633e+03
# sb    1.627548e+05
# dtype: float64

# %%
print(np.log10(ser1))
# Out:
# ar    1.079181
# pd    0.301030
# ra    0.477121
# sb    0.698970
# dtype: float64

# %%
print(np.log10(ser1+ser2))
# Out:
# ar    1.230449
# pd    0.903090
# ra    0.845098
# sb    1.079181
# dtype: float64

# %% [markdown]
# #### CREATING DATA FRAME

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
data=randn(5,5)

# %%
index=(['a','b','c','d','e'])

# %%
head=(['x','y','z','xy','ty'])

# %%
pf=pd.DataFrame(data,index,head)

# %%
pf
# Out:
#           x         y         z        xy        ty
# a  2.706850  0.628133  0.907969  0.503826  0.651118
# b -0.319318 -0.848077  0.605965 -2.018168  0.740122
# c  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# d  0.955057  0.190794  1.978757  2.605967  0.683509
# e  0.302665  1.693723 -1.706086 -1.159119 -0.134841

# %%
type(pf)
# Out:
# pandas.core.frame.DataFrame

# %%
pf["x"]
# Out:
# a    2.706850
# b   -0.319318
# c    0.528813
# d    0.955057
# e    0.302665
# Name: x, dtype: float64

# %%
type(pf["x"])
# Out:
# pandas.core.series.Series

# %%
pf[0:]                              #indexing
# Out:
#           x         y         z        xy        ty
# a  2.706850  0.628133  0.907969  0.503826  0.651118
# b -0.319318 -0.848077  0.605965 -2.018168  0.740122
# c  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# d  0.955057  0.190794  1.978757  2.605967  0.683509
# e  0.302665  1.693723 -1.706086 -1.159119 -0.134841

# %%
pf[3:]
# Out:
#           x         y         z        xy        ty
# d  0.955057  0.190794  1.978757  2.605967  0.683509
# e  0.302665  1.693723 -1.706086 -1.159119 -0.134841

# %%
pf[['x','y']]
# Out:
#           x         y
# a  2.706850  0.628133
# b -0.319318 -0.848077
# c  0.528813 -0.589001
# d  0.955057  0.190794
# e  0.302665  1.693723

# %% [markdown]
# ### inserting a new column

# %%
pf['new']=pf['x']+pf['y']          #new column inserted

# %%
pf                                 #addition of tw0 column(x+y)
# Out:
#           x         y         z        xy        ty       new
# a  2.706850  0.628133  0.907969  0.503826  0.651118  3.334983
# b -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.167395
# c  0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.060187
# d  0.955057  0.190794  1.978757  2.605967  0.683509  1.145851
# e  0.302665  1.693723 -1.706086 -1.159119 -0.134841  1.996388

# %%
pf['run']=pf['z']+pf['ty']

# %%
pf
# Out:
#           x         y         z        xy        ty       new       run
# a  2.706850  0.628133  0.907969  0.503826  0.651118  3.334983  1.559087
# b -0.319318 -0.848077  0.605965 -2.018168  0.740122 -1.167395  1.346087
# c  0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.060187 -0.744542
# d  0.955057  0.190794  1.978757  2.605967  0.683509  1.145851  2.662266
# e  0.302665  1.693723 -1.706086 -1.159119 -0.134841  1.996388 -1.840927

# %%
pf.drop('new',axis=1,inplace=True)    #competely removes the new colounm

# %%
pf.drop('run',axis=1,inplace=True)

# %%
pf
# Out:
#           x         y         z        xy        ty
# a  2.706850  0.628133  0.907969  0.503826  0.651118
# b -0.319318 -0.848077  0.605965 -2.018168  0.740122
# c  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# d  0.955057  0.190794  1.978757  2.605967  0.683509
# e  0.302665  1.693723 -1.706086 -1.159119 -0.134841

# %%
pf.shape
# Out:
# (5, 5)

# %% [markdown]
# ### label base location rows

# %%
pf.loc['c']
# Out:
# x     0.528813
# y    -0.589001
# z     0.188695
# xy   -0.758872
# ty   -0.933237
# Name: c, dtype: float64

# %% [markdown]
# ### index location of row

# %%
pf.iloc[2]
# Out:
# x     0.528813
# y    -0.589001
# z     0.188695
# xy   -0.758872
# ty   -0.933237
# Name: c, dtype: float64

# %%
pf.loc[['a','b'],['z','y']]   # subsets in the data
# Out:
#           z         y
# a  0.907969  0.628133
# b  0.605965 -0.848077

# %%
pf.loc['d','xy']                #index
# Out:
# 2.60596727979128

# %%
pf
# Out:
#           x         y         z        xy        ty
# a  2.706850  0.628133  0.907969  0.503826  0.651118
# b -0.319318 -0.848077  0.605965 -2.018168  0.740122
# c  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# d  0.955057  0.190794  1.978757  2.605967  0.683509
# e  0.302665  1.693723 -1.706086 -1.159119 -0.134841

# %% [markdown]
# conditional selection for the dataframe its give the returns the boolen function

# %%
pf>0              #greater than 0 its returns the true and less than false
# Out:
#        x      y      z     xy     ty
# a   True   True   True   True   True
# b  False  False   True  False   True
# c   True  False   True  False  False
# d   True   True   True   True   True
# e   True   True  False  False  False

# %%
a=pf.loc[['a','b','c']]>1

# %%
a
# Out:
#        x      y      z     xy     ty
# a   True  False  False  False  False
# b  False  False  False  False  False
# c  False  False  False  False  False

# %%
pf[a]
# Out:
#          x   y   z  xy  ty
# a  2.70685 NaN NaN NaN NaN
# b      NaN NaN NaN NaN NaN
# c      NaN NaN NaN NaN NaN
# d      NaN NaN NaN NaN NaN
# e      NaN NaN NaN NaN NaN

# %%
pf
# Out:
#           x         y         z        xy        ty
# a  2.706850  0.628133  0.907969  0.503826  0.651118
# b -0.319318 -0.848077  0.605965 -2.018168  0.740122
# c  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# d  0.955057  0.190794  1.978757  2.605967  0.683509
# e  0.302665  1.693723 -1.706086 -1.159119 -0.134841

# %%
pf>0
# Out:
#        x      y      z     xy     ty
# a   True   True   True   True   True
# b  False  False   True  False   True
# c   True  False   True  False  False
# d   True   True   True   True   True
# e   True   True  False  False  False

# %%
boolen=pf>0

# %%
pf[boolen]
# Out:
#           x         y         z        xy        ty
# a  2.706850  0.628133  0.907969  0.503826  0.651118
# b       NaN       NaN  0.605965       NaN  0.740122
# c  0.528813       NaN  0.188695       NaN       NaN
# d  0.955057  0.190794  1.978757  2.605967  0.683509
# e  0.302665  1.693723       NaN       NaN       NaN

# %%
pf[pf>1]
# Out:
#          x         y         z        xy  ty
# a  2.70685       NaN       NaN       NaN NaN
# b      NaN       NaN       NaN       NaN NaN
# c      NaN       NaN       NaN       NaN NaN
# d      NaN       NaN  1.978757  2.605967 NaN
# e      NaN  1.693723       NaN       NaN NaN

# %%
pf.x>0
# Out:
# a     True
# b    False
# c     True
# d     True
# e     True
# Name: x, dtype: bool

# %%
pf['x']
# Out:
# a    2.706850
# b   -0.319318
# c    0.528813
# d    0.955057
# e    0.302665
# Name: x, dtype: float64

# %%
pf[boolen]
# Out:
#           x         y         z        xy        ty
# a  2.706850  0.628133  0.907969  0.503826  0.651118
# b       NaN       NaN  0.605965       NaN  0.740122
# c  0.528813       NaN  0.188695       NaN       NaN
# d  0.955057  0.190794  1.978757  2.605967  0.683509
# e  0.302665  1.693723       NaN       NaN       NaN

# %% [markdown]
# fillna method

# %%
pf['z'].fillna(0)
# Out:
# a    0.907969
# b    0.605965
# c    0.188695
# d    1.978757
# e   -1.706086
# Name: z, dtype: float64

# %% [markdown]
# ### groupby

# %%
new_data={'company':['google','google','mrsf','mrsf','amz'],
           'persons':['a','b','c','d','e'],
          "sales":[200,150,140,120,500]}

# %%
s=pd.DataFrame(new_data)

# %%
s
# Out:
#   company persons  sales
# 0  google       a    200
# 1  google       b    150
# 2    mrsf       c    140
# 3    mrsf       d    120
# 4     amz       e    500

# %%
a=s.groupby("company")

# %%
a.sum()
# Out:
#         persons  sales
# company
# amz           e    500
# google       ab    350
# mrsf         cd    260

# %%
a["sales"].sum().loc['amz']
# Out:
# 500

# %%
a.describe().transpose()["amz"]
# Out:
# sales  count      1.0
#        mean     500.0
#        std        NaN
#        min      500.0
#        25%      500.0
#        50%      500.0
#        75%      500.0
#        max      500.0
# Name: amz, dtype: float64

# %%
a["sales"].std()
# Out:
# company
# amz             NaN
# google    35.355339
# mrsf      14.142136
# Name: sales, dtype: float64

# %%
a.count()
# Out:
#          persons  sales
# company
# amz            1      1
# google         2      2
# mrsf           2      2

# %%
a["sales"].max()
# Out:
# company
# amz       500
# google    200
# mrsf      140
# Name: sales, dtype: int64

# %%
a["sales"].min()
# Out:
# company
# amz       500
# google    150
# mrsf      120
# Name: sales, dtype: int64

# %%
s["company"].head(0)
# Out:
# Series([], Name: company, dtype: object)

# %%
s["persons"].head(2)
# Out:
# 0    a
# 1    b
# Name: persons, dtype: object

# %%
s["company"].tail(2)
# Out:
# 3    mrsf
# 4     amz
# Name: company, dtype: object

# %%
s["company"].unique()
# Out:
# array(['google', 'mrsf', 'amz'], dtype=object)

# %%
s["company"].nunique()
# Out:
# 3

# %% [markdown]
# new dataframe

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df=pd.DataFrame(randn(5,4),['A','B','C','D','E'],['X','Y','Z','Zz'])

# %%
df
# Out:
#           X         Y         Z        Zz
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df>0
# Out:
#        X      Y      Z     Zz
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False
# D   True  False  False   True
# E   True   True   True   True

# %%
df[df>0]
# Out:
#           X         Y         Z        Zz
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
[df['X']>0]
# Out:
# [A     True
#  B     True
#  C    False
#  D     True
#  E     True
#  Name: X, dtype: bool]

# %%
df["X"]
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: X, dtype: float64

# %%
df[df['X']>0][['Y','Z']]
# Out:
#           Y         Z
# A  0.628133  0.907969
# B -0.319318 -0.848077
# D -0.758872 -0.933237
# E  1.978757  2.605967

# %%
df[(df['Y']>0) & (df['Z']>1)]
# Out:
#           X         Y         Z        Zz
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           X         Y         Z        Zz
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[(df["X"]>1) | (df["Z"])]
# Out:
#           X         Y         Z        Zz
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# ### Reset a index into column

# %%
df.reset_index()
# Out:
#   index         X         Y         Z        Zz
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057
# 4     E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           X         Y         Z        Zz
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
new="Q W E R T".split()

# %%
df["label"]=new

# %%
df
# Out:
#           X         Y         Z        Zz label
# A  2.706850  0.628133  0.907969  0.503826     Q
# B  0.651118 -0.319318 -0.848077  0.605965     W
# C -2.018168  0.740122  0.528813 -0.589001     E
# D  0.188695 -0.758872 -0.933237  0.955057     R
# E  0.190794  1.978757  2.605967  0.683509     T

# %%
df.set_index("label")
# Out:
#               X         Y         Z        Zz
# label
# Q      2.706850  0.628133  0.907969  0.503826
# W      0.651118 -0.319318 -0.848077  0.605965
# E     -2.018168  0.740122  0.528813 -0.589001
# R      0.188695 -0.758872 -0.933237  0.955057
# T      0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           X         Y         Z        Zz label
# A  2.706850  0.628133  0.907969  0.503826     Q
# B  0.651118 -0.319318 -0.848077  0.605965     W
# C -2.018168  0.740122  0.528813 -0.589001     E
# D  0.188695 -0.758872 -0.933237  0.955057     R
# E  0.190794  1.978757  2.605967  0.683509     T

# %% [markdown]
# missing data

# %%
d={"a":[1,2,np.nan],'b':[4,np.nan,np.nan],'c':[1,5,6]}

# %%
df=pd.DataFrame(d)

# %%
df
# Out:
#      a    b  c
# 0  1.0  4.0  1
# 1  2.0  NaN  5
# 2  NaN  NaN  6

# %%
df.dropna()
# Out:
#      a    b  c
# 0  1.0  4.0  1

# %%
df.dropna(axis=0,thresh=2)
# Out:
#      a    b  c
# 0  1.0  4.0  1
# 1  2.0  NaN  5

# %%
df.fillna("aa")
# Out:
#      a    b  c
# 0  1.0  4.0  1
# 1  2.0   aa  5
# 2   aa   aa  6

# %%
df["a"].mean()
# Out:
# 1.5

# %%
df
# Out:
#      a    b  c
# 0  1.0  4.0  1
# 1  2.0  NaN  5
# 2  NaN  NaN  6

# %%
df["c"].mean()
# Out:
# 4.0

# %%
df["c"].sum()
# Out:
# 12

# %%
import pandas as pd

# %%
x={'col1':[1,2,3,4],
  'col2':[444,555,666,777],
  'col3':['abc','def','ghi','jkl']}

# %%
x=pd.DataFrame(x)
x.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   777  jkl

# %%
x
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   777  jkl

# %%
x['col1'].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
x["col2"].nunique()
# Out:
# 4

# %%
x['col2'].sum()
# Out:
# 2442

# %%
x['col2']>500
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# Name: col2, dtype: bool

# %%
def times1(y):
    returns(y*2)

# %%
x['col2']
# Out:
# 0    444
# 1    555
# 2    666
# 3    777
# Name: col2, dtype: int64

# %%
x['col1'].apply(lambda y: y*2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
x.drop('col1',axis=1)
# Out:
#    col2 col3
# 0   444  abc
# 1   555  def
# 2   666  ghi
# 3   777  jkl

# %%
x
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   777  jkl

# %%
x.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
x.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
x.isnull()
# Out:
#     col1   col2   col3
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
d = pd.read_csv(R"C:\\Users\\RAHUL\\Desktop\\kaggledata\\kaggledata.csv")
pf = pd.DataFrame(d)
pf
# Out:
#     fips           state   densityMi   pop2024   pop2023   pop2020  \
# 0      1         Alabama   101.15897   5123196   5098746   5031362
# 1      2          Alaska     1.28344    732385    732984    732923
# 2      4         Arizona    66.44574   7547837   7453517   7179943
# 3      5        Arkansas    59.20375   3080667   3063152   3014195
# 4      6      California   249.08392  38802044  38915693  39501653
# 5      8        Colorado    56.89956   5897184   5868555   5784865
# 6      9     Connecticut   750.08364   3631905   3629055   3597362
# 7     10        Delaware   536.46691   1045574   1031985    992114
# 8     12         Florida   430.36515  23078331  22661577  21589602
# 9     13         Georgia   194.08777  11162570  11037723  10729828
# 10    15          Hawaii   222.05823   1426280   1433238   1451043
# 11    16           Idaho    24.30298   2008471   1973752   1849202
# 12    17        Illinois   222.86349  12373158  12477595  12786580
# ...

# %%
pf.head()
# Out:
#    fips       state  densityMi   pop2024   pop2023   pop2020     pop2019  \
# 0     1     Alabama  101.15897   5123196   5098746   5031362   5006199.4
# 1     2      Alaska    1.28344    732385    732984    732923    730653.8
# 2     4     Arizona   66.44574   7547837   7453517   7179943   7101150.4
# 3     5    Arkansas   59.20375   3080667   3063152   3014195   3004367.3
# 4     6  California  249.08392  38802044  38915693  39501653  39276883.3
#
#     pop2010  growthRate  growth  growthSince2010  \
# 0   4779736     0.00480   24450          0.07186
# 1    710231    -0.00082    -599          0.03119
# 2   6392017     0.01265   94320          0.18082
# 3   2915918     0.00572   17515          0.05650
# 4  37253956    -0.00292 -113649          0.04155
#
#                   CPARequirementsCreditsToSitForExam  \
# 0                                                150
# 1  120 (BA) or within 18 sem. hours of completing BA
# 2                                           120 (BA)
# ...

# %%
pf.tail()
# Out:
#     fips          state  densityMi  pop2024  pop2023  pop2020    pop2019  \
# 45    51       Virginia  221.22378  8736127  8709873  8636471  8572926.3
# 46    53     Washington  118.51252  7875868  7830827  7724031  7624081.9
# 47    54  West Virginia   72.98511  1754416  1764786  1791420  1797577.4
# 48    55      Wisconsin  109.26207  5917415  5904977  5896271  5875342.5
# 49    56        Wyoming    6.02697   585177   583279   577605   576207.1
#
#     pop2010  growthRate  growth  growthSince2010  \
# 45  8001024     0.00301   26254          0.09188
# 46  6724540     0.00575   45041          0.17121
# 47  1852994    -0.00588  -10370         -0.05320
# 48  5686986     0.00211   12438          0.04052
# 49   563626     0.00325    1898          0.03824
#
#    CPARequirementsCreditsToSitForExam CPARequirementsCreditsForLicense  \
# 45                           120 (BA)                              150
# 46             Within 180 days of CER                              150
# ...

# %%
pf
# Out:
#     fips           state   densityMi   pop2024   pop2023   pop2020  \
# 0      1         Alabama   101.15897   5123196   5098746   5031362
# 1      2          Alaska     1.28344    732385    732984    732923
# 2      4         Arizona    66.44574   7547837   7453517   7179943
# 3      5        Arkansas    59.20375   3080667   3063152   3014195
# 4      6      California   249.08392  38802044  38915693  39501653
# 5      8        Colorado    56.89956   5897184   5868555   5784865
# 6      9     Connecticut   750.08364   3631905   3629055   3597362
# 7     10        Delaware   536.46691   1045574   1031985    992114
# 8     12         Florida   430.36515  23078331  22661577  21589602
# 9     13         Georgia   194.08777  11162570  11037723  10729828
# 10    15          Hawaii   222.05823   1426280   1433238   1451043
# 11    16           Idaho    24.30298   2008471   1973752   1849202
# 12    17        Illinois   222.86349  12373158  12477595  12786580
# ...

# %%
pf.describe()
# Out:
#             fips    densityMi       pop2024       pop2023       pop2020  \
# count  50.000000    50.000000  5.000000e+01  5.000000e+01  5.000000e+01
# mean   29.320000   207.851854  6.702435e+06  6.677375e+06  6.616813e+06
# std    15.782243   274.039076  7.513352e+06  7.481574e+06  7.435967e+06
# min     1.000000     1.283440  5.851770e+05  5.832790e+05  5.776050e+05
# 25%    17.250000    48.305813  1.984614e+06  1.972657e+06  1.877562e+06
# 50%    29.500000   106.900815  4.520140e+06  4.535708e+06  4.579554e+06
# 75%    41.750000   222.662175  7.793860e+06  7.736500e+06  7.588009e+06
# max    56.000000  1257.706690  3.880204e+07  3.891569e+07  3.950165e+07
#
#             pop2019       pop2010  growthRate         growth  growthSince2010  \
# count  5.000000e+01  5.000000e+01   50.000000      50.000000        50.000000
# mean   6.571419e+06  6.162876e+06    0.003617   25059.820000         0.086400
# std    7.375948e+06  6.848235e+06    0.007205  100173.637575         0.078485
# ...

# %%
pf.shape
# Out:
# (50, 20)

# %%
pf[10:40:5]
# Out:
#     fips          state  densityMi  pop2024  pop2023  pop2020    pop2019  \
# 10    15         Hawaii  222.05823  1426280  1433238  1451043  1441968.8
# 15    20         Kansas   35.90560  2935606  2936378  2937919  2929438.9
# 20    25  Massachusetts  893.14641  6966542  6974258  6995729  6950919.0
# 25    30        Montana    7.94352  1156147  1139507  1087075  1077309.0
# 30    35     New Mexico   17.36779  2106678  2110011  2118390  2112468.9
# 35    40       Oklahoma   59.43509  4076950  4048375  3964912  3943555.9
#
#     pop2010  growthRate  growth  growthSince2010  \
# 10  1360301    -0.00485   -6958          0.04850
# 15  2853118    -0.00026    -772          0.02891
# 20  6547629    -0.00111   -7716          0.06398
# 25   989415     0.01460   16640          0.16852
# 30  2059179    -0.00158   -3333          0.02307
# 35  3751351     0.00706   28575          0.08680
#
#               CPARequirementsCreditsToSitForExam  \
# 10  120 (BA) or within 120 days of completing BA
# ...

# %%
pf['state']
# Out:
# 0            Alabama
# 1             Alaska
# 2            Arizona
# 3           Arkansas
# 4         California
# 5           Colorado
# 6        Connecticut
# 7           Delaware
# 8            Florida
# 9            Georgia
# 10            Hawaii
# 11             Idaho
# 12          Illinois
# 13           Indiana
# 14              Iowa
# 15            Kansas
# 16          Kentucky
# 17         Louisiana
# 18             Maine
# 19          Maryland
# 20     Massachusetts
# 21          Michigan
# 22         Minnesota
# 23       Mississippi
# 24          Missouri
# 25           Montana
# 26          Nebraska
# 27            Nevada
# 28     New Hampshire
# 29        New Jersey
# 30        New Mexico
# 31          New York
# 32    North Carolina
# 33      North Dakota
# 34              Ohio
# 35          Oklahoma
# 36            Oregon
# 37      Pennsylvania
# 38      Rhode Island
# 39    South Carolina
# 40      South Dakota
# 41         Tennessee
# 42             Texas
# ...

# %%
pf[['state','growth','densityMi']].head(10)
# Out:
#          state  growth  densityMi
# 0      Alabama   24450  101.15897
# 1       Alaska    -599    1.28344
# 2      Arizona   94320   66.44574
# 3     Arkansas   17515   59.20375
# 4   California -113649  249.08392
# 5     Colorado   28629   56.89956
# 6  Connecticut    2850  750.08364
# 7     Delaware   13589  536.46691
# 8      Florida  416754  430.36515
# 9      Georgia  124847  194.08777

# %%
pf[['state','densityMi','growth']][1:40:2]
# Out:
#              state   densityMi  growth
# 1           Alaska     1.28344    -599
# 3         Arkansas    59.20375   17515
# 5         Colorado    56.89956   28629
# 7         Delaware   536.46691   13589
# 9          Georgia   194.08777  124847
# 11           Idaho    24.30298   34719
# 13         Indiana   191.81731   19505
# 15          Kansas    35.90560    -772
# 17       Louisiana   104.53956  -36857
# 19        Maryland   633.02359   -9950
# 21        Michigan   177.35246   -3391
# 23     Mississippi    62.25090   -9529
# 25         Montana     7.94352   16640
# 27          Nevada    29.51797   31370
# 29      New Jersey  1257.70669   -6262
# 31        New York   409.88985 -180341
# 33    North Dakota    11.33194    1327
# 35        Oklahoma    59.43509   28575
# 37    Pennsylvania   288.13236  -40051
# 39  South Carolina   181.67626   89368

# %%
for rec in pf.iterrows():
    print(rec)
# Out:
# (0, fips                                                                                  1
# state                                                                           Alabama
# densityMi                                                                     101.15897
# pop2024                                                                         5123196
# pop2023                                                                         5098746
# pop2020                                                                         5031362
# pop2019                                                                       5006199.4
# pop2010                                                                         4779736
# growthRate                                                                       0.0048
# growth                                                                            24450
# growthSince2010                                                                 0.07186
# ...

# %%
pf.loc[3]    #its represent rows
# Out:
# fips                                          5
# state                                  Arkansas
# densityMi                              59.20375
# pop2024                                 3080667
# pop2023                                 3063152
# pop2020                                 3014195
# pop2019                               3004367.3
# pop2010                                 2915918
# growthRate                              0.00572
# growth                                    17515
# growthSince2010                          0.0565
# CPARequirementsCreditsToSitForExam          150
# CPARequirementsCreditsForLicense            150
# CPARequirementsAge                          NaN
# CPARequirementsCitizenship                   No
# CPARequirementsResidency                     No
# CPARequirementsSocialSecurity               Yes
# CPARequirementsExperience                   Yes
# CPARequirementsEthicsExam                    No
# CPARequirementsAdditionalDetails            NaN
# ...

# %%
pf.loc[10,["state","growth",'growthRate']] #its row number and column name
# Out:
# state          Hawaii
# growth          -6958
# growthRate   -0.00485
# Name: 10, dtype: object

# %%
pf.loc[1:10]
# Out:
#     fips        state  densityMi   pop2024   pop2023   pop2020     pop2019  \
# 1      2       Alaska    1.28344    732385    732984    732923    730653.8
# 2      4      Arizona   66.44574   7547837   7453517   7179943   7101150.4
# 3      5     Arkansas   59.20375   3080667   3063152   3014195   3004367.3
# 4      6   California  249.08392  38802044  38915693  39501653  39276883.3
# 5      8     Colorado   56.89956   5897184   5868555   5784865   5709298.1
# 6      9  Connecticut  750.08364   3631905   3629055   3597362   3595035.5
# 7     10     Delaware  536.46691   1045574   1031985    992114    982696.0
# 8     12      Florida  430.36515  23078331  22661577  21589602  21310772.8
# 9     13      Georgia  194.08777  11162570  11037723  10729828  10625610.5
# 10    15       Hawaii  222.05823   1426280   1433238   1451043   1441968.8
#
#      pop2010  growthRate  growth  growthSince2010  \
# 1     710231    -0.00082    -599          0.03119
# ...

# %%
pf.loc[1:10,"state"]
# Out:
# 1          Alaska
# 2         Arizona
# 3        Arkansas
# 4      California
# 5        Colorado
# 6     Connecticut
# 7        Delaware
# 8         Florida
# 9         Georgia
# 10         Hawaii
# Name: state, dtype: object

# %%
pf.loc[1:5,["state","growth"]]
# Out:
#         state  growth
# 1      Alaska    -599
# 2     Arizona   94320
# 3    Arkansas   17515
# 4  California -113649
# 5    Colorado   28629

# %%
pf.loc[1:10,"state":"growth"]    # range includes for colunm also
# Out:
#           state  densityMi   pop2024   pop2023   pop2020     pop2019  \
# 1        Alaska    1.28344    732385    732984    732923    730653.8
# 2       Arizona   66.44574   7547837   7453517   7179943   7101150.4
# 3      Arkansas   59.20375   3080667   3063152   3014195   3004367.3
# 4    California  249.08392  38802044  38915693  39501653  39276883.3
# 5      Colorado   56.89956   5897184   5868555   5784865   5709298.1
# 6   Connecticut  750.08364   3631905   3629055   3597362   3595035.5
# 7      Delaware  536.46691   1045574   1031985    992114    982696.0
# 8       Florida  430.36515  23078331  22661577  21589602  21310772.8
# 9       Georgia  194.08777  11162570  11037723  10729828  10625610.5
# 10       Hawaii  222.05823   1426280   1433238   1451043   1441968.8
#
#      pop2010  growthRate  growth
# 1     710231    -0.00082    -599
# 2    6392017     0.01265   94320
# 3    2915918     0.00572   17515
# 4   37253956    -0.00292 -113649
# 5    5029196     0.00488   28629
# ...

# %% [markdown]
# ### iloc

# %%
pf.iloc[10,7]
# Out:
# 1360301

# %%
pf.iloc[1:5,1:7]
# Out:
#         state  densityMi   pop2024   pop2023   pop2020     pop2019
# 1      Alaska    1.28344    732385    732984    732923    730653.8
# 2     Arizona   66.44574   7547837   7453517   7179943   7101150.4
# 3    Arkansas   59.20375   3080667   3063152   3014195   3004367.3
# 4  California  249.08392  38802044  38915693  39501653  39276883.3

# %%
pf.iloc[1:5,7]  #selecting a column for range
# Out:
# 1      710231
# 2     6392017
# 3     2915918
# 4    37253956
# Name: pop2010, dtype: int64

# %%
pf.iloc[[10,20,30]]   #random rows are given as input
# Out:
#     fips          state  densityMi  pop2024  pop2023  pop2020    pop2019  \
# 10    15         Hawaii  222.05823  1426280  1433238  1451043  1441968.8
# 20    25  Massachusetts  893.14641  6966542  6974258  6995729  6950919.0
# 30    35     New Mexico   17.36779  2106678  2110011  2118390  2112468.9
#
#     pop2010  growthRate  growth  growthSince2010  \
# 10  1360301    -0.00485   -6958          0.04850
# 20  6547629    -0.00111   -7716          0.06398
# 30  2059179    -0.00158   -3333          0.02307
#
#               CPARequirementsCreditsToSitForExam  \
# 10  120 (BA) or within 120 days of completing BA
# 20                                      120 (BA)
# 30                                      120 (BA)
#
#    CPARequirementsCreditsForLicense  CPARequirementsAge  \
# 10                              150                18.0
# 20                              150                18.0
# 30                              150                 NaN
#
# ...

# %%
pf.iloc[:,[1,2,7]]
# Out:
#              state   densityMi   pop2010
# 0          Alabama   101.15897   4779736
# 1           Alaska     1.28344    710231
# 2          Arizona    66.44574   6392017
# 3         Arkansas    59.20375   2915918
# 4       California   249.08392  37253956
# 5         Colorado    56.89956   5029196
# 6      Connecticut   750.08364   3574097
# 7         Delaware   536.46691    897934
# 8          Florida   430.36515  18801310
# 9          Georgia   194.08777   9687653
# 10          Hawaii   222.05823   1360301
# 11           Idaho    24.30298   1567582
# 12        Illinois   222.86349  12830632
# 13         Indiana   191.81731   6483802
# 14            Iowa    57.39966   3046355
# 15          Kansas    35.90560   2853118
# 16        Kentucky   114.56597   4339367
# 17       Louisiana   104.53956   4533372
# 18           Maine    45.44123   1328361
# 19        Maryland   633.02359   5773552
# 20   Massachusetts   893.14641   6547629
# 21        Michigan   177.35246   9883640
# ...

# %%
pf.iloc[1:10,[1,2,7]]
# Out:
#          state  densityMi   pop2010
# 1       Alaska    1.28344    710231
# 2      Arizona   66.44574   6392017
# 3     Arkansas   59.20375   2915918
duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
# ti remove the duplicates we use 
#          drop_duplicates() its use for tempory
#           drop_duplicates(inplace=True) its delets permenent

# %% [markdown]
# ### handling missing data

# %%
pf
# Out:
#     fips           state   densityMi   pop2024   pop2023   pop2020  \
# 0      1         Alabama   101.15897   5123196   5098746   5031362
# 1      2          Alaska     1.28344    732385    732984    732923
# 2      4         Arizona    66.44574   7547837   7453517   7179943
# 3      5        Arkansas    59.20375   3080667   3063152   3014195
# 4      6      California   249.08392  38802044  38915693  39501653
# 5      8        Colorado    56.89956   5897184   5868555   5784865
# 6      9     Connecticut   750.08364   3631905   3629055   3597362
# 7     10        Delaware   536.46691   1045574   1031985    992114
# 8     12         Florida   430.36515  23078331  22661577  21589602
# 9     13         Georgia   194.08777  11162570  11037723  10729828
# 10    15          Hawaii   222.05823   1426280   1433238   1451043
# 11    16           Idaho    24.30298   2008471   1973752   1849202
# 12    17        Illinois   222.86349  12373158  12477595  12786580
# ...

# %%
pf.fillna(20)
# Out:
#     fips           state   densityMi   pop2024   pop2023   pop2020  \
# 0      1         Alabama   101.15897   5123196   5098746   5031362
# 1      2          Alaska     1.28344    732385    732984    732923
# 2      4         Arizona    66.44574   7547837   7453517   7179943
# 3      5        Arkansas    59.20375   3080667   3063152   3014195
# 4      6      California   249.08392  38802044  38915693  39501653
# 5      8        Colorado    56.89956   5897184   5868555   5784865
# 6      9     Connecticut   750.08364   3631905   3629055   3597362
# 7     10        Delaware   536.46691   1045574   1031985    992114
# 8     12         Florida   430.36515  23078331  22661577  21589602
# 9     13         Georgia   194.08777  11162570  11037723  10729828
# 10    15          Hawaii   222.05823   1426280   1433238   1451043
# 11    16           Idaho    24.30298   2008471   1973752   1849202
# 12    17        Illinois   222.86349  12373158  12477595  12786580
# ...

# %%
pf.dropna()
# Out:
#     fips    state  densityMi  pop2024  pop2023  pop2020    pop2019  pop2010  \
# 0      1  Alabama  101.15897  5123196  5098746  5031362  5006199.4  4779736
# 10    15   Hawaii  222.05823  1426280  1433238  1451043  1441968.8  1360301
# 13    18  Indiana  191.81731  6872047  6852542  6788799  6758299.3  6483802
#
#     growthRate  growth  growthSince2010  \
# 0      0.00480   24450          0.07186
# 10    -0.00485   -6958          0.04850
# 13     0.00285   19505          0.05988
#
#               CPARequirementsCreditsToSitForExam  \
# 0                                            150
# 10  120 (BA) or within 120 days of completing BA
# 13               varies (see Additional Details)
#
#    CPARequirementsCreditsForLicense  CPARequirementsAge  \
# 0                               150                19.0
# 10                              150                18.0
# 13                              150                18.0
#
#    CPARequirementsCitizenship CPARequirementsResidency  \
# ...

# %%
# delete the date permenently 
# dropna(inplace=True)

# %% [markdown]
# ### conditions

# %%
pf
# Out:
#     fips           state   densityMi   pop2024   pop2023   pop2020  \
# 0      1         Alabama   101.15897   5123196   5098746   5031362
# 1      2          Alaska     1.28344    732385    732984    732923
# 2      4         Arizona    66.44574   7547837   7453517   7179943
# 3      5        Arkansas    59.20375   3080667   3063152   3014195
# 4      6      California   249.08392  38802044  38915693  39501653
# 5      8        Colorado    56.89956   5897184   5868555   5784865
# 6      9     Connecticut   750.08364   3631905   3629055   3597362
# 7     10        Delaware   536.46691   1045574   1031985    992114
# 8     12         Florida   430.36515  23078331  22661577  21589602
# 9     13         Georgia   194.08777  11162570  11037723  10729828
# 10    15          Hawaii   222.05823   1426280   1433238   1451043
# 11    16           Idaho    24.30298   2008471   1973752   1849202
# 12    17        Illinois   222.86349  12373158  12477595  12786580
# ...

# %%
pf.loc[pf["state"].str.contains("ar")]
# Out:
#     fips           state  densityMi   pop2024   pop2023   pop2020     pop2019  \
# 7     10        Delaware  536.46691   1045574   1031985    992114    982696.0
# 19    24        Maryland  633.02359   6144760   6154710   6173205   6133239.7
# 32    37  North Carolina  225.53682  10965149  10832061  10449445  10358048.8
# 39    45  South Carolina  181.67626   5461370   5372002   5131848   5081199.6
#
#     pop2010  growthRate  growth  growthSince2010  \
# 7    897934     0.01317   13589          0.16442
# 19  5773552    -0.00162   -9950          0.06429
# 32  9535483     0.01229  133088          0.14993
# 39  4625364     0.01664   89368          0.18074
#
#    CPARequirementsCreditsToSitForExam CPARequirementsCreditsForLicense  \
# 7                            120 (BA)                              150
# 19                           120 (BA)                              150
# 32                           120 (BA)                              150
# ...

# %%
pf.loc[pf["state"].str.startswith("Ar")]
# Out:
#    fips     state  densityMi  pop2024  pop2023  pop2020    pop2019  pop2010  \
# 2     4   Arizona   66.44574  7547837  7453517  7179943  7101150.4  6392017
# 3     5  Arkansas   59.20375  3080667  3063152  3014195  3004367.3  2915918
#
#    growthRate  growth  growthSince2010 CPARequirementsCreditsToSitForExam  \
# 2     0.01265   94320          0.18082                           120 (BA)
# 3     0.00572   17515          0.05650                                150
#
#   CPARequirementsCreditsForLicense  CPARequirementsAge  \
# 2                              150                18.0
# 3                              150                 NaN
#
#   CPARequirementsCitizenship CPARequirementsResidency  \
# 2                         No                       No
# 3                         No                       No
#
#   CPARequirementsSocialSecurity CPARequirementsExperience  \
# 2                           Yes                       Yes
# ...

# %%
pf.loc[pf["state"].str.endswith("na")]
# Out:
#     fips           state  densityMi   pop2024   pop2023   pop2020     pop2019  \
# 2      4         Arizona   66.44574   7547837   7453517   7179943   7101150.4
# 13    18         Indiana  191.81731   6872047   6852542   6788799   6758299.3
# 17    22       Louisiana  104.53956   4516527   4553384   4651664   4639834.8
# 25    30         Montana    7.94352   1156147   1139507   1087075   1077309.0
# 32    37  North Carolina  225.53682  10965149  10832061  10449445  10358048.8
# 39    45  South Carolina  181.67626   5461370   5372002   5131848   5081199.6
#
#     pop2010  growthRate  growth  growthSince2010  \
# 2   6392017     0.01265   94320          0.18082
# 13  6483802     0.00285   19505          0.05988
# 17  4533372    -0.00809  -36857         -0.00372
# 25   989415     0.01460   16640          0.16852
# 32  9535483     0.01229  133088          0.14993
# 39  4625364     0.01664   89368          0.18074
#
# ...

# %%
pf.to_csv("C:\\Users\\RAHUL\\Desktop\\kaggledata.txts,inplace=True")
