# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
import seaborn as sns

# %% [markdown]
# ![Seaborn](Seaborn12.jpg)

# %%
data=sns.load_dataset("tips")

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
print(data.head(10))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
data.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# ### Displot

# %%
sns.distplot(data['total_bill'],kde=True)



plt.show()

# %%
sns.displot(data["total_bill"],kde=False)
plt.show()

# %%
sns.histplot(data["total_bill"])

plt.show()

# %% [markdown]
# ### kernel density esimate

# %%
sns.distplot(data["total_bill"],hist=False)

plt.show()

# %% [markdown]
# ### joinplot

# %%
sns.jointplot(x="total_bill",y="tip",data=data,hue="sex")


plt.show()

# %% [markdown]
# ### scatter plot same as the jointplot

# %%
sns.scatterplot(x="total_bill",y="tip",data=data,hue="total_bill",style="sex")


plt.show()

# %%
#pairplot
sns.set_style("ticks")
sns.pairplot(data)

plt.show()

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(data=data, x ="size", stat="percent",discrete=True)
plt.show()

# %%
sns.histplot(data=data, x ="size", stat="percent")
plt.show()

# %%
sns.histplot(data=data, x ="day", hue="sex",multiple="dodge",shrink=0.8)
plt.show()

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x="smoker",y="total_bill",data=data,hue="sex",estimator=np.mean)
plt.show()

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x="day",y="total_bill",data=data,hue="sex",kind="box")
plt.show()

# %%
sns.countplot(x="sex",data=data)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.regplot(x="total_bill",y="tip",data=data,color='red',marker="*",
           line_kws=dict(color="c",linestyle="--"),
           scatter_kws=dict(color="g",s=100,alpha=0.8),ci=60) #any nurmic)


plt.show()

# %% [markdown]
# ### EXAMPLE KAGGLE DATA

# %%
pf=pd.read_csv(r"C:\\Users\\RAHUL\\Desktop\\kaggledata\\SalesStore.csv")

# %%
pf
# Out:
#      Order_Date   Ship_Date Ship_Mode  Postal_Code   Region Product_Reference  \
# 0    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10022901
# 1    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10023012
# 2    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10002828
# 3    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10022901
# 4    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10000482
# ..          ...         ...       ...          ...      ...               ...
# 211  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10021890
# 212  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10022901
# 213  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10002727
# 214  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10021890
# 215  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10000481
#
# ...

# %% [markdown]
# ### Relplot
# -scatterplot
# -lineplot
#
# uses
# kind
#
# by deflaut its takes scatterplot

# %%
sns.relplot(x="Sales",y="Profit",data=pf,palette="State")

plt.show()

# %%
sns.relplot(x="Sales",y="Profit",data=pf,hue="Category",style="Region",size="Region")

plt.show()

# %%
sns.relplot(x='Sales',y='Profit',data=pf,hue="Category",style="Region",size="Quantity",sizes=(50,100))


plt.show()

# %%
plt.figure(figsize=(10,10))
sns.relplot(x='Order_Date',y='Profit',data=pf,kind="line")


plt.xticks(rotation="vertical")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.relplot(x="Order_Date",y="Profit",data=pf,kind="line",estimator=None)

plt.xticks(rotation="vertical")

plt.show()

# %%
sns.relplot(x="Sales",y="Profit",data=pf,kind="line",col="Region")#col_wrap=2) its show the size of the fig in the region
plt.show()

# %%
sns.relplot(x="Order_Date",y="Sales",data=pf,col="Region",kind='line',hue="Category")
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# ### CATEGORICAL

# %%
pf
# Out:
#      Order_Date   Ship_Date Ship_Mode  Postal_Code   Region Product_Reference  \
# 0    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10022901
# 1    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10023012
# 2    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10002828
# 3    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10022901
# 4    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10000482
# ..          ...         ...       ...          ...      ...               ...
# 211  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10021890
# 212  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10022901
# 213  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10002727
# 214  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10021890
# 215  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10000481
#
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="Region",y="Profit",data=pf,hue="Category")
plt.xticks(rotation="vertical")

plt.show()

# %%
sns.catplot(x="Region",y="Sales",data=pf,kind="box")

#sns.boxplot(x="Region",y="Sales",data=pf)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Region",data=pf,hue="Category")
plt.show()

# %%
pf["Region"].value_counts()
# Out:
# Region
# South      76
# Midwest    61
# West       49
# East       30
# Name: count, dtype: int64

# %%
sns.violinplot(x="Region",y="Quantity",data=pf)


plt.show()

# %%
plt.figure(figsize=(10,5))
sns.stripplot(x="Region",y="Profit",data=pf,hue="State")

plt.show()

# %%
sns.swarmplot(x="Region",y="Profit",data=pf,hue="Category")

plt.show()

# %% [markdown]
# ### DISTRIBUTION PLOT
#
# displot
# histplot
# kdc
# ecdf
# joinplot
# pairplot

# %%
pf
# Out:
#      Order_Date   Ship_Date Ship_Mode  Postal_Code   Region Product_Reference  \
# 0    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10022901
# 1    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10023012
# 2    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10002828
# 3    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10022901
# 4    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10000482
# ..          ...         ...       ...          ...      ...               ...
# 211  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10021890
# 212  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10022901
# 213  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10002727
# 214  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10021890
# 215  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10000481
#
# ...

# %%
sns.histplot(x="Sales",data=pf,kde=True)

plt.show()

# %%
sns.histplot(y="Profit",data=pf,binwidth=None)

plt.show()

# %%
sns.histplot(x='Sales',data=pf,hue="Region",element="poly",fill=False)

plt.show()

# %%
sns.histplot(x="Profit",data=pf,hue="Region",element="step",fill=True,multiple="stack")

plt.show()

# %%
plt.figure(figsize=(10,5))
sns.rugplot(x="Sales",y="Profit",data=pf,hue="Region",height=0.05)

plt.show()

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(x="Sales",y="Profit",data=pf,hue="Region",fill=False)
sns.rugplot(x="Sales",y="Profit",data=pf,hue="Region",height=0.05)

plt.show()

# %%
sns.pairplot(data=pf,kind="hist")

plt.show()

# %%
sns.pairplot(pf,vars=["Sales","Profit","Postal_Code"],kind="reg",hue="Region")#kind="reg" or diag_kind="kde"

plt.show()

# %%
sns.pairplot(data=pf,diag_kws=dict(color="g",kde=True),plot_kws=dict(color="r"))

plt.show('')

# %% [markdown]
# ### REGRESSION(regplot)

# %%
pf
# Out:
#      Order_Date   Ship_Date Ship_Mode  Postal_Code   Region Product_Reference  \
# 0    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10022901
# 1    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10023012
# 2    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10002828
# 3    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10022901
# 4    2021-02-15  2021-02-20    Ground        44104  Midwest  OFF-TAP-10000482
# ..          ...         ...       ...          ...      ...               ...
# 211  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10021890
# 212  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10022901
# 213  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10002727
# 214  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10021890
# 215  2024-01-09  2024-01-14    Ground        20004     East  ELE-PRI-10000481
#
# ...

# %%
sns.regplot(x="Sales",y="Profit",data=pf)

plt.show()

# %%
sns.regplot(x="Sales",y="Profit",data=pf,color="g",marker="*",
           line_kws=dict(color="blue",linestyle="--"),
           scatter_kws=dict(color='g',s=250))
#sns.despine()
plt.show()

# %% [markdown]
# ### matrix
#
#
# heatmap
# cluster

# %%
df=pd.read_excel(r"C:\Users\RAHUL\Desktop\kaggledata\mart.xlsx")

# %%
df
# Out:
#        Unnamed: 0 Item_ID     Item_W      Item_Type    Item_MRP Outlet_ID  \
# 0               0   FDU32  21.027499   Baking Goods  197.352319    OUT046
# 1               1   NCT54  21.102371           Meat  148.250214    OUT035
# 2               2   FDW08  20.882263    Hard Drinks  205.465010    OUT035
# 3               3   FDJ22  21.050435  Starchy Foods  253.417583    OUT046
# 4               4   FDF47  21.247876   Baking Goods  240.871039    OUT035
# ...           ...     ...        ...            ...         ...       ...
# 87859       87859   FDG24   9.994412      Breakfast  147.389893    OUT035
# 87860       87860   FDA32  11.259252         Canned  127.965666    OUT049
# 87861       87861   FDM04  11.385812      Household  119.028901    OUT018
# 87862       87862   NCS18  18.018028      Household  223.416318    OUT018
# 87863       87863   FDQ11  17.130290    Snack Foods  143.232047    OUT013
#
#        Outlet_Year Outlet_Size Outlet_Location_Type        Sales  Tier
# ...

# %%
df1=df.pivot_table(index="Outlet_Year",columns="Outlet_Size",values="Sales")

# %%
df1
# Out:
# Outlet_Size         High       Medium        Small
# Outlet_Year
# 1987         2015.037160  1792.973492  1917.302712
# 1988         1695.209700  1444.865311  1641.739583
# 1996         2265.268983  2272.371502  2219.790139
# 1997         2029.428925  1826.732664  1903.967543
# 1998         2306.542273  2279.666103  2233.775392
# 1999         2004.082749  1850.282194  1909.920236
# 2003         2261.028030  2158.063891  2190.118601
# 2004         1966.898730  1826.582596  1889.009488
# 2005         1935.238262  1010.230431  1215.937098
# 2007         2180.578424  2213.387887  2567.411612
# 2008         2169.407763  1900.378559  2201.448849
# 2009         1923.770187  1554.601061  1890.260032

# %%
sns.set_style("white")
sns.heatmap(df1,annot=True,
           fmt='.1f',
           annot_kws=dict(size=15,weight="bold"),
           linewidths=1,
           linecolor="g")
sns.despine()
plt.show()

# %%
df1.corr()
# Out:
# Outlet_Size      High    Medium     Small
# Outlet_Size
# High         1.000000  0.814985  0.738825
# Medium       0.814985  1.000000  0.927492
# Small        0.738825  0.927492  1.000000

# %%
sns.heatmap(df1.corr(),
           vmin=-1,
           vmax=1,
           center=0,
           annot=True,
           fmt=".1f",
           annot_kws=dict(size=15,weight="bold"),
           linewidth=0.5,
           linecolor="k")

plt.show()

# %%
sns.clustermap(df1)
plt.show()

# %%
sns.clustermap(df1,
             # col_cluster=False,
              row_cluster=False,
              annot=True,
              fmt=".0f",standard_scale=1)

plt.show()

# %% [markdown]
# ### facetgrid

# %%
import seaborn as sns
df
# Out:
#        Unnamed: 0 Item_ID     Item_W      Item_Type    Item_MRP Outlet_ID  \
# 0               0   FDU32  21.027499   Baking Goods  197.352319    OUT046
# 1               1   NCT54  21.102371           Meat  148.250214    OUT035
# 2               2   FDW08  20.882263    Hard Drinks  205.465010    OUT035
# 3               3   FDJ22  21.050435  Starchy Foods  253.417583    OUT046
# 4               4   FDF47  21.247876   Baking Goods  240.871039    OUT035
# ...           ...     ...        ...            ...         ...       ...
# 87859       87859   FDG24   9.994412      Breakfast  147.389893    OUT035
# 87860       87860   FDA32  11.259252         Canned  127.965666    OUT049
# 87861       87861   FDM04  11.385812      Household  119.028901    OUT018
# 87862       87862   NCS18  18.018028      Household  223.416318    OUT018
# 87863       87863   FDQ11  17.130290    Snack Foods  143.232047    OUT013
#
#        Outlet_Year Outlet_Size Outlet_Location_Type        Sales  Tier
# ...

# %%
df.Outlet_Size.unique()
# Out:
# array(['Small', 'Medium', 'High'], dtype=object)

# %%
df.Item_Type.unique()
# Out:
# array(['Baking Goods', 'Meat', 'Hard Drinks', 'Starchy Foods', 'Breads',
#        'Others', 'Seafood', 'Fruits and Vegetables', 'Soft Drinks',
#        'Household', 'Snack Foods', 'Frozen Foods', 'Health and Hygiene',
#        'Canned', 'Dairy', 'Breakfast'], dtype=object)

# %%
f=sns.FacetGrid(df,col="Outlet_Size")
f.map_dataframe(sns.histplot,x="Outlet_Year",y="Sales")
plt.show()

# %%
f=sns.FacetGrid(df,col="Outlet_Size")
f.map_dataframe(sns.histplot,x="Sales")

plt.show()

# %%
f=sns.FacetGrid(df,col="Outlet_Size")
f.map_dataframe(sns.kdeplot,x="Sales",)

plt.show()
