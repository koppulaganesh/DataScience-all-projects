# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import plotly.express as px

# %%
ts1=pd.read_csv(r"C:\Users\RAHUL\Desktop\kaggledata\Wl_task2.csv")

# %%
ts1=pd.DataFrame(ts1)

# %%
ts1.head(2)
# Out:
#    Unnamed: 0                     Date       Energy  Resistance  Current  \
# 0       16645  2023-03-10 16:06:05.180  5279.587891       272.0     7.10
# 1       16650  2023-03-10 16:06:59.390  5284.775879       270.0     7.13
#
#    Voltage         Power  uipvalue weldpoint      score prediction  year  \
# 0     1.88  13342.919922        80     T0391   8.137701     Passed  2023
# 1     1.84  13123.620117        96     T0391  15.128845     Passed  2023
#
#    month  day     id
# 0      3   10  Train
# 1      3   10  Train

# %%
ts1
# Out:
#       Unnamed: 0                     Date       Energy  Resistance  Current  \
# 0          16645  2023-03-10 16:06:05.180  5279.587891       272.0     7.10
# 1          16650  2023-03-10 16:06:59.390  5284.775879       270.0     7.13
# 2          16651  2023-03-10 16:00:49.570  5229.563965       267.0     7.15
# 3          16660  2023-03-10 16:44:37.850  5402.745117       273.0     7.16
# 4          16661  2023-03-10 16:45:25.860  5341.735840       274.0     7.10
# ...          ...                      ...          ...         ...      ...
# 8448       94288  2023-08-08 14:11:31.360  5510.055176       277.0     7.16
# 8449       94289  2023-08-08 14:00:20.180  5404.756836       277.0     7.09
# 8450       94290  2023-08-08 14:01:13.470  5384.125000       276.0     7.10
# 8451       94291  2023-08-08 14:06:30.710  5395.432129       277.0     7.10
# 8452       94292  2023-08-08 14:07:19.430  5414.668945       278.0     7.10
#
# ...

# %%
sns.boxplot(x="id",y="Voltage",data=ts1,hue="id")
plt.ylabel("Voltage",size=15,c="b")
plt.xlabel("id",size=15,c="b")

plt.show()

# %%
sns.boxplot(x="id",y="Power",data=ts1,hue="id")
plt.show()

# %%
sns.boxplot(x="id",y="Energy",data=ts1,hue="id")
plt.xlabel("id",size=15)
plt.show()

# %%
sns.boxplot(x="id",y="Resistance",data=ts1,hue="id")

plt.show()

# %%
sns.countplot(x="prediction",data=ts1,edgecolor="k",saturation=1)

plt.show()

# %%
ts1
# Out:
#       Unnamed: 0                     Date       Energy  Resistance  Current  \
# 0          16645  2023-03-10 16:06:05.180  5279.587891       272.0     7.10
# 1          16650  2023-03-10 16:06:59.390  5284.775879       270.0     7.13
# 2          16651  2023-03-10 16:00:49.570  5229.563965       267.0     7.15
# 3          16660  2023-03-10 16:44:37.850  5402.745117       273.0     7.16
# 4          16661  2023-03-10 16:45:25.860  5341.735840       274.0     7.10
# ...          ...                      ...          ...         ...      ...
# 8448       94288  2023-08-08 14:11:31.360  5510.055176       277.0     7.16
# 8449       94289  2023-08-08 14:00:20.180  5404.756836       277.0     7.09
# 8450       94290  2023-08-08 14:01:13.470  5384.125000       276.0     7.10
# 8451       94291  2023-08-08 14:06:30.710  5395.432129       277.0     7.10
# 8452       94292  2023-08-08 14:07:19.430  5414.668945       278.0     7.10
#
# ...

# %%
ts2=ts1['Date'] = pd.to_datetime(ts1['Date'])
ts2=ts1_sorted = ts1.sort_values(by='Date')

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x="Date",y="score",data=ts2)
plt.title("Line Plot",size=45,color="red")
plt.xlabel("Date",size=20,color="green")
plt.ylabel("score",size=20,color="green")
plt.show()
